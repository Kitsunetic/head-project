# %%
import numpy as np
import pandas as pd
import imageio
import h5py
import pickle

from tqdm import tqdm
from xqdm import xqdm
from pathlib import Path
import matplotlib.pyplot as plt

# %%
with open('data/data.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
data_series = [11, 12, 13, 21, 22, 23, 31, 32, 33, 41, 42, 43, 51, 52, 53, 61, 62, 63, 71, 72, 73]

# %%
df = data[data_series[0]]

# %%
timestamp = df['timestamp']
yaw = df['input_orientation_yaw']
pitch = df['input_orientation_pitch']
roll = df['input_orientation_roll']

# %%
dyaw, dpitch, droll = [], [], []

for i in range(len(df)-1):
    l = timestamp[i + 1]
    for j in range(i+2, len(df)):
        timestamp[j]
# Out:
# 0
# 1
# 12
# 13
# 14
# 15
# 16
# 17
# 264
# 265
# 266
# 267
# 268
# 269
# 270
# 271
# 272
# 273
# 274
# 524
# 526
# 527
# 528
# 529
# 531
# 576
# 577
# 578
# 579
# 580
# 581
# 994
# 995
# 996
# 997
# 998
# 999
# 7200
# 7206

# %%
plt.figure(figsize=(12, 3))
plt.subplot(1, 3, 1)
plt.plot(dyaw)
plt.subplot(1, 3, 2)
plt.plot(dpitch)
plt.subplot(1, 3, 3)
plt.plot(droll)
plt.tight_layout()
plt.show()

# %%
plt.plot(df['timestamp'][:10])

# %%
df['timestamp'][1] - df['timestamp'][0]
# Out:
# 131947580

# %%
df['timestamp'][2] - df['timestamp'][1]
# Out:
# 5099805
